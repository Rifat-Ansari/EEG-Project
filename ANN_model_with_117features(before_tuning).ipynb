# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 
# Reproducibility

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
# import warnings
import warnings
# filter warnings
warnings.filterwarnings('ignore')
np.random.seed(0)
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %%
# import important library
import glob
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import seaborn as sns
from scipy import stats
import os
from collections import Counter

# %matplotlib inline
import pickle
import warnings
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder
from sklearn.base import clone
from sklearn.preprocessing import label_binarize
from scipy import interp
from sklearn.metrics import roc_curve, auc 

from matplotlib.legend_handler import HandlerLine2D
import time

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score

from xgboost import XGBClassifier

from sklearn.metrics import accuracy_score
#from sklearn.externals import joblib

# %%
f_vector = pd.read_csv('/content/drive/MyDrive/CSE499B_data/Feature_vector_108 (2).csv')
f_vector.head()
# Out:
#        f1c1      f1c2      f1c3      f1c4      f1c5      f1c6      f1c7  \
# 0  2.260318  2.349516  2.285102  2.371036  1.723475  2.354274  1.938889
# 1  0.328330  0.380961  0.402019  0.302958  0.721228  0.672094  0.279890
# 2  1.319238  1.649933  1.764590  1.534097  1.306506  2.514998  1.442240
# 3  0.881155  0.549112 -0.009987  0.481874  0.616842  0.255339  0.236800
# 4  2.480299  2.159354  2.323685  1.121081  2.003411  1.788438  2.149194
#
#        f1c8      f1c9       f2c1  ...      p5c1      p5c2      p5c3      p5c4  \
# 0  2.088486  1.822621   4.532200  ...  2.847430  2.468363  2.475560  2.852187
# 1  0.338119  0.285035   1.727734  ...  2.638754  2.326181  2.539087  2.771569
# 2  2.010884  1.819087   6.019772  ...  1.797214  1.589979  1.508731  1.750036
# 3 -0.273485  0.047532   5.899954  ...  2.795483  2.967400  2.478721  3.613074
# 4  1.761871  1.609207  18.623084  ...  1.722872  1.842653  1.870039  2.220646
#
#        p5c5      p5c6      p5c7      p5c8      p5c9  label
# 0  3.900093  2.878861  3.402330  3.174722  3.616891      0
# 1  3.194668  2.511841  2.843321  2.855719  3.362964      0
# 2  1.837351  1.716106  1.886707  1.613818  1.696078      0
# 3  4.194302  3.455086  3.332238  3.230821  3.102742      0
# 4  2.627883  2.439646  2.240589  2.656710  2.838000      0
#
# [5 rows x 118 columns]

# %%
X = f_vector.drop('label',axis='columns')
y = f_vector['label']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
import tensorflow as tf
from tensorflow import keras


model = keras.Sequential([
    keras.layers.Dense(117, input_shape=(117,), activation='relu'),
    keras.layers.Dense(60, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 1s 9ms/step - loss: 12.8137 - accuracy: 0.4688
# Epoch 2/50
# 2/2 [==============================] - 0s 7ms/step - loss: 5.3052 - accuracy: 0.5156
# Epoch 3/50
# 2/2 [==============================] - 0s 6ms/step - loss: 5.0485 - accuracy: 0.5625
# Epoch 4/50
# 2/2 [==============================] - 0s 7ms/step - loss: 3.2459 - accuracy: 0.6250
# Epoch 5/50
# 2/2 [==============================] - 0s 7ms/step - loss: 3.0903 - accuracy: 0.5469
# Epoch 6/50
# 2/2 [==============================] - 0s 7ms/step - loss: 2.9043 - accuracy: 0.6250
# Epoch 7/50
# 2/2 [==============================] - 0s 8ms/step - loss: 2.0624 - accuracy: 0.5781
# Epoch 8/50
# 2/2 [==============================] - 0s 7ms/step - loss: 1.7073 - accuracy: 0.6406
# Epoch 9/50
# 2/2 [==============================] - 0s 7ms/step - loss: 1.8743 - accuracy: 0.6719
# Epoch 10/50
# 2/2 [==============================] - 0s 7ms/step - loss: 1.8526 - accuracy: 0.6875
# Epoch 11/50
# 2/2 [==============================] - 0s 8ms/step - loss: 1.2987 - accuracy: 0.7188
# Epoch 12/50
# 2/2 [==============================] - 0s 8ms/step - loss: 1.2315 - accuracy: 0.7500
# Epoch 13/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8794 - accuracy: 0.7500
# Epoch 14/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9804 - accuracy: 0.7344
# Epoch 15/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9787 - accuracy: 0.7188
# Epoch 16/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9142 - accuracy: 0.7656
# Epoch 17/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7931 - accuracy: 0.7812
# Epoch 18/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9410 - accuracy: 0.7656
# Epoch 19/50
# 2/2 [==============================] - 0s 6ms/step - loss: 1.1530 - accuracy: 0.7031
# Epoch 20/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6071 - accuracy: 0.8125
# Epoch 21/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7608 - accuracy: 0.7656
# Epoch 22/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5707 - accuracy: 0.8125
# Epoch 23/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.9348 - accuracy: 0.7188
# Epoch 24/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4997 - accuracy: 0.8594
# Epoch 25/50
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7409 - accuracy: 0.7812
# Epoch 26/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5900 - accuracy: 0.7500
# Epoch 27/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4408 - accuracy: 0.8281
# Epoch 28/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4133 - accuracy: 0.8594
# Epoch 29/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4445 - accuracy: 0.8281
# Epoch 30/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4400 - accuracy: 0.8438
# Epoch 31/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3387 - accuracy: 0.8594
# Epoch 32/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3871 - accuracy: 0.8594
# Epoch 33/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2748 - accuracy: 0.8906
# Epoch 34/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2946 - accuracy: 0.8750
# Epoch 35/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2544 - accuracy: 0.8906
# Epoch 36/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2737 - accuracy: 0.9062
# Epoch 37/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2613 - accuracy: 0.8906
# Epoch 38/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3389 - accuracy: 0.8594
# Epoch 39/50
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2568 - accuracy: 0.8750
# Epoch 40/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2743 - accuracy: 0.8906
# Epoch 41/50
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1869 - accuracy: 0.9531
# Epoch 42/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2585 - accuracy: 0.8594
# Epoch 43/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2342 - accuracy: 0.9062
# Epoch 44/50
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2097 - accuracy: 0.9375
# Epoch 45/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2357 - accuracy: 0.8750
# Epoch 46/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1687 - accuracy: 0.9219
# Epoch 47/50
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1985 - accuracy: 0.9375
# Epoch 48/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2743 - accuracy: 0.8125
# Epoch 49/50
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2453 - accuracy: 0.8906
# Epoch 50/50
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1603 - accuracy: 0.9688

# %%
test_eval = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])
# Out:
# Test loss: 1.4479836225509644
# Test accuracy: 0.7058823704719543

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 33ms/step - loss: 1.4480 - accuracy: 0.7059
# [1.4479836225509644, 0.7058823704719543]

# %%
yp = model.predict(X_test)
y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.40      0.44         5
#            1       0.77      0.83      0.80        12
#
#     accuracy                           0.71        17
#    macro avg       0.63      0.62      0.62        17
# weighted avg       0.69      0.71      0.70        17
