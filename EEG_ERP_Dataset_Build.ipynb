# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import torch
torch.manual_seed(100)

# %% [markdown]
# #Data Loading

# %%
dataset = pd.read_csv('/content/drive/MyDrive/499B_Final _Dataset/ERP/ERPdata.csv')
dataset.head()
# Out:
#    subject  condition        Fz       FCz        Cz       FC3       FC4  \
# 0        1          1  5.533701  5.726507  5.469535  5.386723  4.588875
# 1        1          1  5.651489  5.837326  5.773131  5.627975  4.822217
# 2        1          1  5.717580  5.932924  5.948466  5.826460  4.979647
# 3        1          1  5.703267  5.968103  5.851512  5.812192  4.992899
# 4        1          1  5.571578  5.917541  5.812808  5.744715  4.963338
#
#          C3        C4       CP3       CP4
# 0  6.560092  4.542811  5.397492  5.103695
# 1  6.739976  4.811770  5.541357  5.379273
# 2  7.026199  5.053779  5.634972  5.600504
# 3  6.940671  5.106650  5.543577  5.589775
# 4  6.726491  5.158073  5.454069  5.614092

# %%
dataset.shape
# Out:
# (746496, 11)

# %%
subject_1 = dataset[dataset['subject']==1]
subject_2 =dataset[dataset['subject']==2]
subject_3 = dataset[dataset['subject']==3]
subject_4 = dataset[dataset['subject']==4]
subject_5 =dataset[dataset['subject']==5]
subject_6 = dataset[dataset['subject']==6]
subject_7 = dataset[dataset['subject']==7]
subject_8 =dataset[dataset['subject']==8]
subject_9 = dataset[dataset['subject']==9]
subject_10 = dataset[dataset['subject']==10]
subject_11=dataset[dataset['subject']==11]
subject_12= dataset[dataset['subject']==12]
subject_13=dataset[dataset['subject']==13]
subject_14= dataset[dataset['subject']==14]
subject_15=dataset[dataset['subject']==15]
subject_16 = dataset[dataset['subject']==16]
subject_17 =dataset[dataset['subject']==17]
subject_18 = dataset[dataset['subject']==18]
subject_19 = dataset[dataset['subject']==19]
subject_20 =dataset[dataset['subject']==20]
subject_21 = dataset[dataset['subject']==21]
subject_22 = dataset[dataset['subject']==22]
subject_23 =dataset[dataset['subject']==23]
subject_24 = dataset[dataset['subject']==24]
subject_25 = dataset[dataset['subject']==25]
subject_26=dataset[dataset['subject']==26]
subject_27= dataset[dataset['subject']==27]
subject_28=dataset[dataset['subject']==28]
subject_29= dataset[dataset['subject']==29]
subject_30=dataset[dataset['subject']==30]
subject_31 = dataset[dataset['subject']==31]
subject_32 =dataset[dataset['subject']==32]
subject_33 = dataset[dataset['subject']==33]
subject_34 = dataset[dataset['subject']==34]
subject_35 =dataset[dataset['subject']==35]
subject_36 = dataset[dataset['subject']==36]
subject_37 = dataset[dataset['subject']==37]
subject_38 =dataset[dataset['subject']==38]
subject_39 = dataset[dataset['subject']==39]
subject_40 = dataset[dataset['subject']==40]
subject_41=dataset[dataset['subject']==41]
subject_42= dataset[dataset['subject']==42]
subject_43=dataset[dataset['subject']==43]
subject_44= dataset[dataset['subject']==44]
subject_45=dataset[dataset['subject']==45]
subject_46 = dataset[dataset['subject']==46]
subject_47 =dataset[dataset['subject']==47]
subject_48 = dataset[dataset['subject']==48]
subject_49 = dataset[dataset['subject']==49]
subject_50 = dataset[dataset['subject']==50]
subject_51=dataset[dataset['subject']==51]
subject_52= dataset[dataset['subject']==52]
subject_53=dataset[dataset['subject']==53]
subject_54= dataset[dataset['subject']==54]
subject_55=dataset[dataset['subject']==55]
subject_56 = dataset[dataset['subject']==56]
subject_57 =dataset[dataset['subject']==57]
subject_58 = dataset[dataset['subject']==58]
subject_59 = dataset[dataset['subject']==59]
subject_60 = dataset[dataset['subject']==60]
subject_61=dataset[dataset['subject']==61]
subject_62= dataset[dataset['subject']==62]
subject_63=dataset[dataset['subject']==63]
subject_64= dataset[dataset['subject']==64]
subject_65=dataset[dataset['subject']==65]
subject_66 = dataset[dataset['subject']==66]
subject_67 =dataset[dataset['subject']==67]
subject_68 = dataset[dataset['subject']==68]
subject_69 = dataset[dataset['subject']==69]
subject_70 = dataset[dataset['subject']==70]
subject_71=dataset[dataset['subject']==71]
subject_72= dataset[dataset['subject']==72]
subject_73=dataset[dataset['subject']==73]
subject_74= dataset[dataset['subject']==74]
subject_75=dataset[dataset['subject']==75]
subject_76 = dataset[dataset['subject']==76]
subject_77 =dataset[dataset['subject']==77]
subject_78 = dataset[dataset['subject']==78]
subject_79 = dataset[dataset['subject']==79]
subject_80 = dataset[dataset['subject']==80]
subject_81 = dataset[dataset['subject']==81]

# %%
path1= '/content/drive/MyDrive/499B_Final _Dataset/ERP/'
subject_1.to_csv(path1+'subject_1.csv', index=None)
subject_2.to_csv(path1+'subject_2.csv', index=None)
subject_3.to_csv(path1+'subject_3.csv', index=None)
subject_4.to_csv(path1+'subject_4.csv', index=None)
subject_5.to_csv(path1+'subject_5.csv', index=None)
subject_6.to_csv(path1+'subject_6.csv', index=None)
subject_7.to_csv(path1+'subject_7.csv', index=None)
subject_8.to_csv(path1+'subject_8.csv', index=None)
subject_9.to_csv(path1+'subject_9.csv', index=None)
subject_10.to_csv(path1+'subject_10.csv', index=None)
subject_11.to_csv(path1+'subject_11.csv', index=None)
subject_12.to_csv(path1+'subject_12.csv', index=None)
subject_13.to_csv(path1+'subject_13.csv', index=None)
subject_14.to_csv(path1+'subject_14.csv', index=None)
subject_15.to_csv(path1+'subject_15.csv', index=None)
subject_16.to_csv(path1+'subject_16.csv', index=None)
subject_17.to_csv(path1+'subject_17.csv', index=None)
subject_18.to_csv(path1+'subject_18.csv', index=None)
subject_19.to_csv(path1+'subject_19.csv', index=None)
subject_20.to_csv(path1+'subject_20.csv', index=None)
subject_21.to_csv(path1+'subject_21.csv', index=None)
subject_22.to_csv(path1+'subject_22.csv', index=None)
subject_23.to_csv(path1+'subject_23.csv', index=None)
subject_24.to_csv(path1+'subject_24.csv', index=None)
subject_25.to_csv(path1+'subject_25.csv', index=None)
subject_26.to_csv(path1+'subject_26.csv', index=None)
subject_27.to_csv(path1+'subject_27.csv', index=None)
subject_28.to_csv(path1+'subject_28.csv', index=None)
subject_29.to_csv(path1+'subject_29.csv', index=None)
subject_30.to_csv(path1+'subject_30.csv', index=None)
subject_31.to_csv(path1+'subject_31.csv', index=None)
subject_32.to_csv(path1+'subject_32.csv', index=None)
subject_33.to_csv(path1+'subject_33.csv', index=None)
subject_34.to_csv(path1+'subject_34.csv', index=None)
subject_35.to_csv(path1+'subject_35.csv', index=None)
subject_36.to_csv(path1+'subject_36.csv', index=None)
subject_37.to_csv(path1+'subject_37.csv', index=None)
subject_38.to_csv(path1+'subject_38.csv', index=None)
subject_39.to_csv(path1+'subject_39.csv', index=None)
subject_40.to_csv(path1+'subject_40.csv', index=None)
subject_41.to_csv(path1+'subject_41.csv', index=None)
subject_42.to_csv(path1+'subject_42.csv', index=None)
subject_43.to_csv(path1+'subject_43.csv', index=None)
subject_44.to_csv(path1+'subject_44.csv', index=None)
subject_45.to_csv(path1+'subject_45.csv', index=None)
subject_46.to_csv(path1+'subject_46.csv', index=None)
subject_47.to_csv(path1+'subject_47.csv', index=None)
subject_48.to_csv(path1+'subject_48.csv', index=None)
subject_49.to_csv(path1+'subject_49.csv', index=None)
subject_50.to_csv(path1+'subject_50.csv', index=None)
subject_51.to_csv(path1+'subject_51.csv', index=None)
subject_52.to_csv(path1+'subject_52.csv', index=None)
subject_53.to_csv(path1+'subject_53.csv', index=None)
subject_54.to_csv(path1+'subject_54.csv', index=None)
subject_55.to_csv(path1+'subject_55.csv', index=None)
subject_56.to_csv(path1+'subject_56.csv', index=None)
subject_57.to_csv(path1+'subject_57.csv', index=None)
subject_58.to_csv(path1+'subject_58.csv', index=None)
subject_59.to_csv(path1+'subject_59.csv', index=None)
subject_60.to_csv(path1+'subject_60.csv', index=None)
subject_61.to_csv(path1+'subject_61.csv', index=None)
subject_62.to_csv(path1+'subject_62.csv', index=None)
subject_63.to_csv(path1+'subject_63.csv', index=None)
subject_64.to_csv(path1+'subject_64.csv', index=None)
subject_65.to_csv(path1+'subject_65.csv', index=None)
subject_66.to_csv(path1+'subject_66.csv', index=None)
subject_67.to_csv(path1+'subject_67.csv', index=None)
subject_68.to_csv(path1+'subject_68.csv', index=None)
subject_69.to_csv(path1+'subject_69.csv', index=None)
subject_70.to_csv(path1+'subject_70.csv', index=None)
subject_71.to_csv(path1+'subject_71.csv', index=None)
subject_72.to_csv(path1+'subject_72.csv', index=None)
subject_73.to_csv(path1+'subject_73.csv', index=None)
subject_74.to_csv(path1+'subject_74.csv', index=None)
subject_75.to_csv(path1+'subject_75.csv', index=None)
subject_76.to_csv(path1+'subject_76.csv', index=None)
subject_77.to_csv(path1+'subject_77.csv', index=None)
subject_78.to_csv(path1+'subject_78.csv', index=None)
subject_79.to_csv(path1+'subject_79.csv', index=None)
subject_80.to_csv(path1+'subject_80.csv', index=None)
subject_81.to_csv(path1+'subject_81.csv', index=None)


#pd.read_csv(path1+'subject_1.csv')

# %%
path1= '/content/drive/MyDrive/499B_Final _Dataset/ERP_20/'
subject_1.to_csv(path1+'subject_1.csv', index=None)
subject_2.to_csv(path1+'subject_2.csv', index=None)
subject_3.to_csv(path1+'subject_3.csv', index=None)
subject_4.to_csv(path1+'subject_4.csv', index=None)
subject_5.to_csv(path1+'subject_5.csv', index=None)
subject_6.to_csv(path1+'subject_6.csv', index=None)
subject_7.to_csv(path1+'subject_7.csv', index=None)
subject_8.to_csv(path1+'subject_8.csv', index=None)
subject_9.to_csv(path1+'subject_9.csv', index=None)
subject_10.to_csv(path1+'subject_10.csv', index=None)
subject_11.to_csv(path1+'subject_11.csv', index=None)
subject_12.to_csv(path1+'subject_12.csv', index=None)
subject_13.to_csv(path1+'subject_13.csv', index=None)
subject_14.to_csv(path1+'subject_14.csv', index=None)
subject_15.to_csv(path1+'subject_15.csv', index=None)
subject_16.to_csv(path1+'subject_16.csv', index=None)
subject_17.to_csv(path1+'subject_17.csv', index=None)
subject_18.to_csv(path1+'subject_18.csv', index=None)
subject_19.to_csv(path1+'subject_19.csv', index=None)
subject_20.to_csv(path1+'subject_20.csv', index=None)

# %%
# !pip install eeglib
# Out:
# ...
#      |████████████████████████████████| 2.4 MB 6.2 MB/s
# ...
